# %% [markdown]
# # Feature Extraction with IMDb Reviews

# %% [markdown]
# # Library Imports

# %%
import pandas as pd
import os
import tensorflow as tf

import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import TfidfVectorizer

# %% [markdown]
# # Loading the Dataset

# %%
url = "https://ai.stanford.edu/~amaas/data/sentiment/aclImdb_v1.tar.gz"
dataset = tf.keras.utils.get_file("aclImdb_v1", url,
                                    untar=True, cache_dir='.',
                                    cache_subdir='')
dataset_dir = os.path.join(os.path.dirname(dataset), 'aclImdb')
# Out:
# Downloading data from https://ai.stanford.edu/~amaas/data/sentiment/aclImdb_v1.tar.gz
# 84131840/84125825 [==============================] - 6s 0us/step
# 84140032/84125825 [==============================] - 6s 0us/step

# %%
os.listdir(dataset_dir)
# Out:
# ['imdb.vocab', 'test', 'README', 'imdbEr.txt', 'train']

# %%
train_dir = os.path.join(dataset_dir, 'train')
os.listdir(train_dir)
# Out:
# ['neg',
#  'urls_neg.txt',
#  'urls_pos.txt',
#  'unsup',
#  'pos',
#  'urls_unsup.txt',
#  'unsupBow.feat',
#  'labeledBow.feat']

# %%
sample_file = os.path.join(train_dir, 'neg/36_4.txt')
with open(sample_file) as f:
  print(f.read())
# Out:
# This film seemed way too long even at only 75 minutes. The problem with jungle horror films is that there is always way too much footage of people walking (through the jungle, up a rocky cliff, near a river or lake) to pad out the running time. The film is worth seeing for the laughable and naked native zombie with big bulging, bloody eyes which is always accompanied on the soundtrack with heavy breathing and lots of reverb. Eurotrash fans will be plenty entertained by the bad English dubbing, gratuitous female flesh and very silly makeup jobs on the monster and native extras. For a zombie/cannibal flick this was pretty light on the gore but then I probably didn't see an uncut version.

# %%
df = pd.DataFrame()
for i in ('test', 'train'):
  for j in ('pos', 'neg'):
    path = os.path.join(dataset_dir, i, j)
    for fl in os.listdir(path):
      with open(os.path.join(path, fl), 'r', encoding = 'utf-8') as f:
        df = df.append([[f.read()]], ignore_index = True)
df.columns = ['review']

# %%
df.head()
# Out:
#                                               review
# 0  My children, DD 7 and DS 10, enjoyed the movie...
# 1  One of the many speculations about Y2K was tha...
# 2  Rajkumar Santoshi tries his hands at comedy an...
# 3  Bridget Fonda has disappointed me several time...
# 4  Watching this movie, I can't help drawing the ...

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
reviewCorpus = df.review.str.cat(sep = ' ')
tokens = word_tokenize(reviewCorpus)
tokens
# Out:
# ['My',
#  'children',
#  ',',
#  'DD',
#  '7',
#  'and',
#  'DS',
#  '10',
#  ',',
#  'enjoyed',
#  'the',
#  'movie',
#  'so',
#  'much',
#  'they',
#  'were',
#  'squirming',
#  'in',
#  'their',
#  'seats',
#  '.',
#  'It',
#  'was',
#  'good',
#  ',',
#  'old',
#  'fashioned',
#  ',',
#  'Rated',
#  'G',
#  ',',
#  'family',
#  'fun',
#  '.',
#  'This',
#  'movie',
#  'was',
#  'made',
#  'for',
#  'kids',
#  '...',
#  '.',
#  'someone',
#  'really',
#  'understands',
#  'them.',
#  '<',
#  'br',
#  '/',
#  '>',
#  '<',
#  'br',
#  '/',
#  '>',
#  'It',
#  'was',
#  'fun',
#  'to',
#  'see',
#  'Julia',
#  'Roberts',
#  ',',
#  'Brice',
#  'Willis',
#  ',',
#  'Garth',
#  'Brooks',
#  'and',
#  'the',
#  'other',
#  'stars',
#  'make',
#  'their',
#  'cameo',
#  'appearances.',
#  '<',
#  'br',
#  '/',
#  '>',
#  '<',
#  'br',
#  '/',
#  '>',
#  'As',
#  'someone',
#  'who',
#  'lives',
#  'in',
#  'the',
#  'city',
#  'the',
#  'fictional',
#  '``',
#  'Big',
#  'Texas',
#  "''",
#  'was',
#  'modeled',
#  'after',
#  ',',
#  'I',
#  'can',
#  'say',
#  'that',
#  'they',
#  'did',
#  'an',
#  'honest',
#  'and',
#  'accurate',
#  'portrayal',
#  '.',
#  'The',
#  'kids',
#  'looked',
#  'like',
#  'kids',
#  ',',
#  'not',
#  'like',
#  'superstars.',
#  '<',
#  'br',
#  '/',
#  '>',
#  '<',
#  'br',
#  '/',
#  '>',
#  'I',
#  'hope',
#  'everyone',
#  'supports',
#  'this',
#  'movie',
#  'to',
#  'send',
#  'the',
#  'message',
#  'to',
#  'Hollywood',
#  'that',
#  'we',
#  'need',
#  'more',
#  'movies',
#  'like',
#  'this',
#  '.',
#  'Go',
#  'see',
#  'it',
#  ',',
#  'then',
#  'spread',
#  'the',
#  'word',
#  '!',
#  'One',
#  'of',
#  'the',
#  'many',
#  'speculations',
#  'about',
#  'Y2K',
#  'was',
#  'that',
#  'the',
#  'world',
#  'was',
#  'going',
#  'to',
#  'end',
#  'at',
#  'the',
#  'stroke',
#  'of',
#  'midnight',
#  'on',
#  'December',
#  '31',
#  ',',
#  '1999',
#  '.',
#  'In',
#  '`The',
#  'Book',
#  'Of',
#  'Life',
#  ',',
#  "'",
#  'writer/director',
#  'Hal',
#  'Hartley',
#  'takes',
#  'a',
#  'look',
#  'at',
#  'the',
#  'possible',
#  'ramifications',
#  'of',
#  'a',
#  'new',
#  'millennium',
#  'Armageddon',
#  ',',
#  'beginning',
#  'with',
#  'the',
#  'return',
#  'of',
#  'Jesus',
#  'to',
#  'Earth',
#  'on',
#  'New',
#  'Year',
#  "'s",
#  'Eve',
#  ',',
#  '\x9199',
#  '.',
#  'The',
#  'story',
#  'examines',
#  'the',
#  'task',
#  'of',
#  'the',
#  'Son',
#  'of',
#  'God',
#  ',',
#  'who',
#  'must',
#  'open',
#  'the',
#  'remaining',
#  'three',
#  'of',
#  'the',
#  'seven',
#  'seals',
#  'contained',
#  'in',
#  'the',
#  'Book',
#  'of',
#  'Life',
#  '(',
#  'now',
#  'contained',
#  'in',
#  'a',
#  'Mac',
#  'laptop',
#  'computer',
#  ')',
#  ',',
#  'in',
#  'which',
#  'there',
#  'is',
#  'also',
#  'the',
#  'names',
#  'of',
#  'the',
#  'one-hundred',
#  'and',
#  'forty-four',
#  'thousand',
#  'good',
#  'souls',
#  'who',
#  'will',
#  'be',
#  'spared',
#  'on',
#  'the',
#  'last',
#  'day',
#  '.',
#  'Jesus',
#  '(',
#  'Martin',
#  'Donovan',
#  ')',
#  ',',
#  'along',
#  'with',
#  'Magdalena',
#  '(',
#  'P.J',
#  'Harvey',
#  ')',
#  ',',
#  'arrives',
#  'in',
#  'New',
#  'York',
#  'City',
#  'to',
#  'make',
#  'the',
#  'preparations',
#  'necessary',
#  'for',
#  'carrying',
#  'out',
#  'his',
#  'Father',
#  "'s",
#  'will',
#  ',',
#  'but',
#  'he',
#  'begins',
#  'to',
#  'have',
#  'second',
#  'thoughts',
#  ';',
#  'must',
#  'he',
#  'judge',
#  'the',
#  'living',
#  'and',
#  'the',
#  'dead',
#  '?',
#  'Do',
#  'they',
#  'deserve',
#  'what',
#  'must',
#  'befall',
#  'them',
#  '?',
#  'It',
#  'is',
#  'a',
#  'cup',
#  'He',
#  'would',
#  'prefer',
#  'not',
#  'to',
#  'embrace',
#  'at',
#  'this',
#  'particular',
#  'moment',
#  ',',
#  'which',
#  'gives',
#  'encouragement',
#  'to',
#  'Satan',
#  '(',
#  'Thomas',
#  'Jay',
#  'Ryan',
#  ')',
#  'who',
#  'fears',
#  'that',
#  'the',
#  'fruit',
#  'of',
#  'all',
#  'his',
#  'hard',
#  'labor',
#  'is',
#  'about',
#  'to',
#  'be',
#  'washed',
#  'away',
#  'at',
#  'midnight',
#  ',',
#  'for',
#  'he',
#  'can',
#  'only',
#  'continue',
#  'his',
#  'work',
#  'so',
#  'long',
#  'as',
#  'there',
#  'are',
#  'people',
#  'around',
#  'who',
#  'cling',
#  'to',
#  'their',
#  'pitiful',
#  'hopes',
#  'and',
#  'dreams',
#  '.',
#  'An',
#  'artistically',
#  'rendered',
#  ',',
#  'high',
#  'concept',
#  'film',
#  ',',
#  'Hartley',
#  'presents',
#  'the',
#  'story',
#  'in',
#  'an',
#  'intelligent',
#  ',',
#  'thought',
#  'provoking',
#  'manner',
#  ',',
#  'taking',
#  'great',
#  'care',
#  'in',
#  'dealing',
#  'with',
#  'the',
#  'sensitive',
#  'subject',
#  'matter',
#  'so',
#  'as',
#  'to',
#  'make',
#  'it',
#  'inoffensive',
#  'even',
#  'to',
#  'the',
#  'most',
#  'ardent',
#  'fundamentalist',
#  '.',
#  'The',
#  'dialogue',
#  'between',
#  'Jesus',
#  'and',
#  'Satan',
#  'is',
#  'intriguing',
#  'and',
#  'stimulating',
#  ',',
#  'as',
#  'is',
#  'the',
#  'effect',
#  'of',
#  'their',
#  'presence',
#  'upon',
#  'those',
#  'they',
#  'encounter',
#  'during',
#  'their',
#  'corporeal',
#  'stay',
#  'in',
#  'the',
#  'city',
#  '.',
#  'It',
#  "'s",
#  'an',
#  'engrossing',
#  'meditation',
#  'on',
#  'the',
#  'spiritual',
#  'side',
#  'of',
#  'Man',
#  "'s",
#  'fragile',
#  'existence',
#  'and',
#  'a',
#  'contemplation',
#  'of',
#  'that',
#  'which',
#  'has',
#  'been',
#  'prophesied',
#  'in',
#  'the',
#  'Revelations',
#  'of',
#  'St.',
#  'John',
#  'in',
#  'the',
#  'Apocalypse',
#  ',',
#  'the',
#  'last',
#  'Book',
#  'of',
#  'the',
#  'New',
#  'Testament',
#  '.',
#  'And',
#  'there',
#  'is',
#  'logic',
#  'in',
#  'Hartley',
#  "'s",
#  'approach',
#  'to',
#  'the',
#  'Second',
#  'Coming',
#  ';',
#  'he',
#  'maintains',
#  'the',
#  'aesthetic',
#  'of',
#  'the',
#  'contemporary',
#  'setting',
#  'while',
#  'employing',
#  'altered',
#  'film',
#  'speeds',
#  'which',
#  'visually',
#  'give',
#  'the',
#  'film',
#  'an',
#  'ethereal',
#  'quality',
#  '.',
#  'Christ',
#  'inconspicuously',
#  'wears',
#  'a',
#  'suit',
#  'and',
#  'tie',
#  ',',
#  'effectively',
#  'blending',
#  'in',
#  'with',
#  'the',
#  'populace',
#  ',',
#  'while',
#  'Satan',
#  "'s",
#  'attire',
#  'is',
#  'a',
#  'bit',
#  'more',
#  'casual',
#  ',',
#  'his',
#  'appearance',
#  'somewhat',
#  'scruffy',
#  ';',
#  'he',
#  'sports',
#  'a',
#  'bruise',
#  'above',
#  'his',
#  'left',
#  'eye',
#  '.',
#  'Donovan',
#  'is',
#  'well',
#  'cast',
#  'as',
#  'Jesus',
#  ',',
#  'lending',
#  'a',
#  'benevolent',
#  'mien',
#  'and',
#  'a',
#  'sense',
#  'of',
#  'restrained',
#  'urgency',
#  'to',
#  'his',
#  'character',
#  'that',
#  'is',
#  'very',
#  'effective',
#  '.',
#  'It',
#  'is',
#  ',',
#  'of',
#  'course',
#  ',',
#  'a',
#  'unique',
#  'portrayal',
#  'of',
#  'The',
#  'Saviour',
#  ',',
#  'and',
#  'possibly',
#  'the',
#  'best',
#  'since',
#  'Max',
#  'von',
#  'Sydow',
#  "'s",
#  'in',
#  '`The',
#  'Greatest',
#  'Story',
#  'Ever',
#  'Told',
#  '.',
#  "'",
#  'He',
#  'successfully',
#  'conveys',
#  'a',
#  'feeling',
#  'of',
#  'inner',
#  'peace',
#  'and',
#  'tranquility',
#  ',',
#  'of',
#  'serenity',
#  ',',
#  'that',
#  'is',
#  'the',
#  'essence',
#  'at',
#  'the',
#  'very',
#  'core',
#  'of',
#  'the',
#  'character',
#  '.',
#  'And',
#  'Ryan',
#  'is',
#  'thoroughly',
#  'engaging',
#  'in',
#  'his',
#  'role',
#  'of',
#  'the',
#  'Prince',
#  'of',
#  'Darkness',
#  ';',
#  'he',
#  'has',
#  'a',
#  'distinct',
#  'manner',
#  'of',
#  'speech',
#  'and',
#  'a',
#  'resonant',
#  'quality',
#  'to',
#  'his',
#  'voice',
#  'that',
#  'make',
#  'him',
#  'absolutely',
#  'mesmerizing',
#  'to',
#  'watch',
#  '.',
#  'His',
#  'eyes',
#  'are',
#  'darkly',
#  'penetrating',
#  ',',
#  'a',
#  'trait',
#  'he',
#  'uses',
#  'effectively',
#  'with',
#  'furtive',
#  'glances',
#  'and',
#  'captivating',
#  'stares',
#  '.',
#  'He',
#  "'s",
#  'the',
#  'guy',
#  'who',
#  'could',
#  'sell',
#  'you',
#  'anything',
#  'in',
#  'exchange',
#  'for',
#  'your',
#  'soul',
#  'before',
#  'you',
#  'ever',
#  'knew',
#  'what',
#  'hit',
#  'you',
#  '.',
#  'It',
#  "'s",
#  'a',
#  'memorable',
#  'performance',
#  'that',
#  'contrasts',
#  'so',
#  'well',
#  'with',
#  'Donovan',
#  "'s",
#  'portrayal',
#  'of',
#  'Jesus',
#  '.',
#  'The',
#  'supporting',
#  'cast',
#  'includes',
#  'Martin',
#  'Pfeffercorn',
#  '(',
#  'Martyr',
#  ')',
#  ',',
#  'Miho',
#  'Nikaido',
#  '(',
#  'Edie',
#  ')',
#  ',',
#  'Dave',
#  'Simonds',
#  '(',
#  'Dave',
#  ')',
#  ',',
#  'D.J',
#  '.',
#  'Mendel',
#  '(',
#  'Lawyer',
#  ')',
#  ',',
#  'James',
#  'Urbaniak',
#  '(',
#  'True',
#  'Believer',
#  ')',
#  ',',
#  'Katreen',
#  'Hardt',
#  '(',
#  'Lawyer',
#  "'s",
#  'Assistant',
#  ')',
#  'and',
#  'Anna',
#  'Kohler',
#  '(',
#  'Hotel',
#  'Clerk',
#  ')',
#  '.',
#  'In',
#  'his',
#  'own',
#  ',',
#  'inimitable',
#  'style',
#  ',',
#  'with',
#  '`The',
#  'Book',
#  'Of',
#  'Life',
#  ',',
#  "'",
#  'Hartley',
#  'has',
#  'crafted',
#  'a',
#  'perspective',
#  'of',
#  'the',
#  'last',
#  'days',
#  'that',
#  'is',
#  'interesting',
#  ',',
#  'entertaining',
#  'and',
#  'truly',
#  'unique',
#  '.',
#  'He',
#  'has',
#  'a',
#  'way',
#  'of',
#  'capturing',
#  'life',
#  'as',
#  'it',
#  'is',
#  'just',
#  'off',
#  'center',
#  ',',
#  'a',
#  'method',
#  'which',
#  'works',
#  'especially',
#  'well',
#  'with',
#  'a',
#  'film',
#  'like',
#  'this',
#  '.',
#  'Comparatively',
#  'short',
#  'for',
#  'a',
#  'feature',
#  'film',
#  '(',
#  'running',
#  'time',
#  'of',
#  '63',
#  'minutes',
#  ')',
#  ',',
#  'it',
#  'nevertheless',
#  'is',
#  'one',
#  'of',
#  'Hartley',
#  "'s",
#  'best',
#  ',',
#  'and',
#  'more',
#  'than',
#  'worth',
#  'the',
#  'price',
#  'of',
#  'admission',
#  '.',
#  'It',
#  "'s",
#  'a',
#  'film',
#  'that',
#  'will',
#  'stay',
#  'with',
#  'you',
#  'and',
#  'perhaps',
#  'make',
#  'you',
#  'think',
#  'about',
#  'some',
#  'things',
#  'you',
#  'may',
#  'have',
#  'tucked',
#  'away',
#  'in',
#  'a',
#  'corner',
#  'of',
#  'your',
#  'mind',
#  'for',
#  'later',
#  '.',
#  'And',
#  'that',
#  'is',
#  'part',
#  'of',
#  'the',
#  'attraction',
#  'of',
#  'this',
#  'film',
#  ';',
#  'it',
#  'makes',
#  'you',
#  'realize',
#  'that',
#  '`later',
#  "'",
#  'most',
#  'likely',
#  'is',
#  'now',
#  '.',
#  'I',
#  'rate',
#  'this',
#  'one',
#  '9/10',
#  '.',
#  'Rajkumar',
#  'Santoshi',
#  'tries',
#  'his',
#  'hands',
#  'at',
#  'comedy',
#  'and',
#  'succeeds',
#  '.',
#  'One',
#  'of',
#  'the',
#  'few',
#  'good',
#  'movies',
#  'that',
#  'involves',
#  'Salman',
#  'Khan',
#  '.',
#  'A',
#  'very',
#  'funny',
#  'movie',
#  'from',
#  'start',
#  'to',
#  'finish',
#  '.',
#  ...]

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
stopWords = set(stopwords.words('english'))
tokens = [word.lower() for word in tokens if ((word not in stopWords) and
          len(word) > 2 and word.isalpha())]
tokens
# Out:
# ['children',
#  'enjoyed',
#  'movie',
#  'much',
#  'squirming',
#  'seats',
#  'good',
#  'old',
#  'fashioned',
#  'rated',
#  'family',
#  'fun',
#  'movie',
#  'made',
#  'kids',
#  'someone',
#  'really',
#  'understands',
#  'fun',
#  'see',
#  'julia',
#  'roberts',
#  'brice',
#  'willis',
#  'garth',
#  'brooks',
#  'stars',
#  'make',
#  'cameo',
#  'someone',
#  'lives',
#  'city',
#  'fictional',
#  'big',
#  'texas',
#  'modeled',
#  'say',
#  'honest',
#  'accurate',
#  'portrayal',
#  'kids',
#  'looked',
#  'like',
#  'kids',
#  'like',
#  'hope',
#  'everyone',
#  'supports',
#  'movie',
#  'send',
#  'message',
#  'hollywood',
#  'need',
#  'movies',
#  'like',
#  'see',
#  'spread',
#  'word',
#  'one',
#  'many',
#  'speculations',
#  'world',
#  'going',
#  'end',
#  'stroke',
#  'midnight',
#  'december',
#  'book',
#  'life',
#  'hal',
#  'hartley',
#  'takes',
#  'look',
#  'possible',
#  'ramifications',
#  'new',
#  'millennium',
#  'armageddon',
#  'beginning',
#  'return',
#  'jesus',
#  'earth',
#  'new',
#  'year',
#  'eve',
#  'story',
#  'examines',
#  'task',
#  'son',
#  'god',
#  'must',
#  'open',
#  'remaining',
#  'three',
#  'seven',
#  'seals',
#  'contained',
#  'book',
#  'life',
#  'contained',
#  'mac',
#  'laptop',
#  'computer',
#  'also',
#  'names',
#  'thousand',
#  'good',
#  'souls',
#  'spared',
#  'last',
#  'day',
#  'jesus',
#  'martin',
#  'donovan',
#  'along',
#  'magdalena',
#  'harvey',
#  'arrives',
#  'new',
#  'york',
#  'city',
#  'make',
#  'preparations',
#  'necessary',
#  'carrying',
#  'father',
#  'begins',
#  'second',
#  'thoughts',
#  'must',
#  'judge',
#  'living',
#  'dead',
#  'deserve',
#  'must',
#  'befall',
#  'cup',
#  'would',
#  'prefer',
#  'embrace',
#  'particular',
#  'moment',
#  'gives',
#  'encouragement',
#  'satan',
#  'thomas',
#  'jay',
#  'ryan',
#  'fears',
#  'fruit',
#  'hard',
#  'labor',
#  'washed',
#  'away',
#  'midnight',
#  'continue',
#  'work',
#  'long',
#  'people',
#  'around',
#  'cling',
#  'pitiful',
#  'hopes',
#  'dreams',
#  'artistically',
#  'rendered',
#  'high',
#  'concept',
#  'film',
#  'hartley',
#  'presents',
#  'story',
#  'intelligent',
#  'thought',
#  'provoking',
#  'manner',
#  'taking',
#  'great',
#  'care',
#  'dealing',
#  'sensitive',
#  'subject',
#  'matter',
#  'make',
#  'inoffensive',
#  'even',
#  'ardent',
#  'fundamentalist',
#  'dialogue',
#  'jesus',
#  'satan',
#  'intriguing',
#  'stimulating',
#  'effect',
#  'presence',
#  'upon',
#  'encounter',
#  'corporeal',
#  'stay',
#  'city',
#  'engrossing',
#  'meditation',
#  'spiritual',
#  'side',
#  'man',
#  'fragile',
#  'existence',
#  'contemplation',
#  'prophesied',
#  'revelations',
#  'john',
#  'apocalypse',
#  'last',
#  'book',
#  'new',
#  'testament',
#  'logic',
#  'hartley',
#  'approach',
#  'second',
#  'coming',
#  'maintains',
#  'aesthetic',
#  'contemporary',
#  'setting',
#  'employing',
#  'altered',
#  'film',
#  'speeds',
#  'visually',
#  'give',
#  'film',
#  'ethereal',
#  'quality',
#  'christ',
#  'inconspicuously',
#  'wears',
#  'suit',
#  'tie',
#  'effectively',
#  'blending',
#  'populace',
#  'satan',
#  'attire',
#  'bit',
#  'casual',
#  'appearance',
#  'somewhat',
#  'scruffy',
#  'sports',
#  'bruise',
#  'left',
#  'eye',
#  'donovan',
#  'well',
#  'cast',
#  'jesus',
#  'lending',
#  'benevolent',
#  'mien',
#  'sense',
#  'restrained',
#  'urgency',
#  'character',
#  'effective',
#  'course',
#  'unique',
#  'portrayal',
#  'saviour',
#  'possibly',
#  'best',
#  'since',
#  'max',
#  'von',
#  'sydow',
#  'greatest',
#  'story',
#  'ever',
#  'told',
#  'successfully',
#  'conveys',
#  'feeling',
#  'inner',
#  'peace',
#  'tranquility',
#  'serenity',
#  'essence',
#  'core',
#  'character',
#  'ryan',
#  'thoroughly',
#  'engaging',
#  'role',
#  'prince',
#  'darkness',
#  'distinct',
#  'manner',
#  'speech',
#  'resonant',
#  'quality',
#  'voice',
#  'make',
#  'absolutely',
#  'mesmerizing',
#  'watch',
#  'eyes',
#  'darkly',
#  'penetrating',
#  'trait',
#  'uses',
#  'effectively',
#  'furtive',
#  'glances',
#  'captivating',
#  'stares',
#  'guy',
#  'could',
#  'sell',
#  'anything',
#  'exchange',
#  'soul',
#  'ever',
#  'knew',
#  'hit',
#  'memorable',
#  'performance',
#  'contrasts',
#  'well',
#  'donovan',
#  'portrayal',
#  'jesus',
#  'supporting',
#  'cast',
#  'includes',
#  'martin',
#  'pfeffercorn',
#  'martyr',
#  'miho',
#  'nikaido',
#  'edie',
#  'dave',
#  'simonds',
#  'dave',
#  'mendel',
#  'lawyer',
#  'james',
#  'urbaniak',
#  'true',
#  'believer',
#  'katreen',
#  'hardt',
#  'lawyer',
#  'assistant',
#  'anna',
#  'kohler',
#  'hotel',
#  'clerk',
#  'inimitable',
#  'style',
#  'book',
#  'life',
#  'hartley',
#  'crafted',
#  'perspective',
#  'last',
#  'days',
#  'interesting',
#  'entertaining',
#  'truly',
#  'unique',
#  'way',
#  'capturing',
#  'life',
#  'center',
#  'method',
#  'works',
#  'especially',
#  'well',
#  'film',
#  'like',
#  'comparatively',
#  'short',
#  'feature',
#  'film',
#  'running',
#  'time',
#  'minutes',
#  'nevertheless',
#  'one',
#  'hartley',
#  'best',
#  'worth',
#  'price',
#  'admission',
#  'film',
#  'stay',
#  'perhaps',
#  'make',
#  'think',
#  'things',
#  'may',
#  'tucked',
#  'away',
#  'corner',
#  'mind',
#  'later',
#  'part',
#  'attraction',
#  'film',
#  'makes',
#  'realize',
#  'likely',
#  'rate',
#  'one',
#  'rajkumar',
#  'santoshi',
#  'tries',
#  'hands',
#  'comedy',
#  'succeeds',
#  'one',
#  'good',
#  'movies',
#  'involves',
#  'salman',
#  'khan',
#  'funny',
#  'movie',
#  'start',
#  'finish',
#  'characters',
#  'contribute',
#  'movie',
#  'believe',
#  'lot',
#  'aamir',
#  'khan',
#  'salman',
#  'khan',
#  'raveena',
#  'tandon',
#  'karishma',
#  'kapoor',
#  'paresh',
#  'rawal',
#  'viju',
#  'khote',
#  'jagdip',
#  'deven',
#  'verma',
#  'shakti',
#  'kapoor',
#  'harish',
#  'patel',
#  'tiku',
#  'talsania',
#  'direction',
#  'editing',
#  'sound',
#  'par',
#  'still',
#  'matter',
#  'actors',
#  'make',
#  'part',
#  'bridget',
#  'fonda',
#  'disappointed',
#  'several',
#  'times',
#  'years',
#  'attention',
#  'break',
#  'true',
#  'story',
#  'missing',
#  'critical',
#  'details',
#  'several',
#  'places',
#  'kept',
#  'scrutinizing',
#  'fonda',
#  'clues',
#  'meaningful',
#  'story',
#  'let',
#  'look',
#  'eyes',
#  'last',
#  'scene',
#  'musters',
#  'courage',
#  'literally',
#  'put',
#  'one',
#  'foot',
#  'front',
#  'toward',
#  'uncertain',
#  'future',
#  'one',
#  'dramatic',
#  'significant',
#  'examples',
#  'face',
#  'acting',
#  'ever',
#  'believed',
#  'completely',
#  'possibly',
#  'known',
#  'admired',
#  'several',
#  'tough',
#  'broads',
#  'survived',
#  'similar',
#  'abusive',
#  'situations',
#  'without',
#  'becoming',
#  'hopeful',
#  'projection',
#  'fonda',
#  'character',
#  'break',
#  'watching',
#  'movie',
#  'help',
#  'drawing',
#  'comparison',
#  'wild',
#  'reeds',
#  'another',
#  'thoughtful',
#  'film',
#  'teenagers',
#  'coming',
#  'like',
#  'wild',
#  'reeds',
#  'movie',
#  'slow',
#  'director',
#  'would',
#  'hurried',
#  'want',
#  'quick',
#  'resolution',
#  'things',
#  'watch',
#  'movie',
#  'like',
#  'slice',
#  'life',
#  'beginning',
#  'imperfectly',
#  'ending',
#  'imperfectly',
#  'resolution',
#  'anything',
#  'happily',
#  'ever',
#  'anybody',
#  'like',
#  'real',
#  'movie',
#  'real',
#  'gets',
#  'acting',
#  'surprisingly',
#  'good',
#  'director',
#  'fond',
#  'long',
#  'really',
#  'long',
#  'shots',
#  'actors',
#  'actresses',
#  'excel',
#  'showing',
#  'subtlety',
#  'inner',
#  'love',
#  'movie',
#  'almost',
#  'watch',
#  'glad',
#  'movie',
#  'everyone',
#  'willing',
#  'let',
#  'grow',
#  'certainly',
#  'one',
#  'hilarious',
#  'films',
#  'time',
#  'excellent',
#  'original',
#  'music',
#  'clever',
#  'heady',
#  'hard',
#  'articulate',
#  'something',
#  'good',
#  'one',
#  'character',
#  'instantly',
#  'love',
#  'myronex',
#  'putney',
#  'trouble',
#  'black',
#  'room',
#  'name',
#  'rufus',
#  'lines',
#  'thrown',
#  'away',
#  'left',
#  'right',
#  'classics',
#  'recalling',
#  'slapshot',
#  'caddyshack',
#  'anchorman',
#  'repoman',
#  'dolemite',
#  'comedy',
#  'whose',
#  'dialog',
#  'formulaic',
#  'punchline',
#  'variety',
#  'putney',
#  'myronex',
#  'called',
#  'tasteless',
#  'organization',
#  'lopez',
#  'head',
#  'sound',
#  'brilliant',
#  'hear',
#  'context',
#  'scene',
#  'movie',
#  'eat',
#  'brain',
#  'good',
#  'read',
#  'reviews',
#  'calling',
#  'film',
#  'racist',
#  'could',
#  'farther',
#  'truth',
#  'every',
#  'scene',
#  'gold',
#  'etherial',
#  'cereal',
#  'commercial',
#  'brothers',
#  'black',
#  'room',
#  'meeting',
#  'haunting',
#  'trumpet',
#  'closing',
#  'scene',
#  'one',
#  'word',
#  'genius',
#  'seeing',
#  'trailer',
#  'easy',
#  'decision',
#  'see',
#  'film',
#  'mean',
#  'care',
#  'stupid',
#  'stoner',
#  'comedies',
#  'sure',
#  'also',
#  'easy',
#  'choice',
#  'lot',
#  'people',
#  'get',
#  'together',
#  'smoke',
#  'bowl',
#  'check',
#  'flick',
#  'guy',
#  'simpsons',
#  'guy',
#  'named',
#  'billy',
#  'bob',
#  'good',
#  'time',
#  'film',
#  'funny',
#  'bad',
#  'somebody',
#  'bum',
#  'unfortunately',
#  'found',
#  'trailer',
#  'misleading',
#  'already',
#  'left',
#  'theaters',
#  'wait',
#  'video',
#  'really',
#  'enjoyed',
#  'nice',
#  'locations',
#  'quality',
#  'production',
#  'excellent',
#  'performances',
#  'entire',
#  'cast',
#  'looking',
#  'back',
#  'plot',
#  'twists',
#  'totally',
#  'unexpected',
#  'find',
#  'cumbersome',
#  'premise',
#  'absorbing',
#  'drama',
#  'marketed',
#  'comedy',
#  'something',
#  'happen',
#  'producer',
#  'leaving',
#  'associate',
#  'producers',
#  'marketing',
#  'sad',
#  'committed',
#  'lasted',
#  'two',
#  'weeks',
#  'dallas',
#  'theaters',
#  'thought',
#  'movie',
#  'lot',
#  'going',
#  'script',
#  'funny',
#  'full',
#  'subtle',
#  'emotional',
#  'shifts',
#  'good',
#  'message',
#  'acting',
#  'great',
#  'everyone',
#  'superb',
#  'job',
#  'especially',
#  'script',
#  'subtleties',
#  'heather',
#  'graham',
#  'beautiful',
#  'eyes',
#  'eyes',
#  'matter',
#  'actors',
#  'attractive',
#  'well',
#  'theatrical',
#  'release',
#  'know',
#  'studio',
#  'seem',
#  'much',
#  'push',
#  'behind',
#  'deserved',
#  'better',
#  'hope',
#  'well',
#  'video',
#  'certainly',
#  'one',
#  'favorites',
#  'first',
#  'half',
#  'films',
#  'deal',
#  'things',
#  'would',
#  'consider',
#  'expert',
#  'one',
#  'years',
#  'fantasy',
#  'role',
#  'playing',
#  'split',
#  'leaving',
#  'without',
#  'sense',
#  'shame',
#  'become',
#  'see',
#  'things',
#  'really',
#  'canonical',
#  'happens',
#  'first',
#  'create',
#  'character',
#  'fairly',
#  'dies',
#  'first',
#  'help',
#  'little',
#  'constitution',
#  'help',
#  'strength',
#  'intelligence',
#  'intuition',
#  'charisma',
#  'dexterity',
#  'turn',
#  'frustrates',
#  'game',
#  'master',
#  'know',
#  'deal',
#  'invincible',
#  'gang',
#  'bores',
#  'players',
#  'start',
#  'create',
#  'ever',
#  'exotic',
#  'combinations',
#  'matter',
#  'ludicrous',
#  'created',
#  'druedain',
#  'warrior',
#  'monk',
#  'yeah',
#  'far',
#  'said',
#  'destructiveness',
#  'inherent',
#  'dynamic',
#  'devilish',
#  'game',
#  'think',
#  'hunt',
#  'experience',
#  'points',
#  'watch',
#  'film',
#  'shows',
#  'course',
#  'stupidity',
#  'basic',
#  'end',
#  'turn',
#  'better',
#  'profession',
#  'bard',
#  'exactly',
#  'understand',
#  'bard',
#  'became',
#  'character',
#  'first',
#  'place',
#  'blacksmith',
#  'none',
#  'became',
#  'one',
#  'mapped',
#  'game',
#  'flow',
#  'made',
#  'lethal',
#  'least',
#  'indirectly',
#  'poking',
#  'fun',
#  'never',
#  'comes',
#  'end',
#  'rightfully',
#  'sure',
#  'exactly',
#  'professional',
#  'production',
#  'seen',
#  'better',
#  'satire',
#  'ages',
#  'first',
#  'saw',
#  'like',
#  'done',
#  'high',
#  'school',
#  'musical',
#  'coast',
#  'along',
#  'making',
#  'appearances',
#  'disney',
#  'shows',
#  'personally',
#  'love',
#  'suite',
#  'life',
#  'big',
#  'fan',
#  'ashely',
#  'tisdale',
#  'reason',
#  'keen',
#  'zac',
#  'efron',
#  'although',
#  'friends',
#  'think',
#  'best',
#  'thing',
#  'since',
#  'jesse',
#  'mccartney',
#  'really',
#  'annoys',
#  'anyway',
#  'watched',
#  'show',
#  'taking',
#  'break',
#  'english',
#  'coursework',
#  'pleasantly',
#  'surprised',
#  'performances',
#  'good',
#  'round',
#  'especially',
#  'regular',
#  'characters',
#  'suite',
#  'life',
#  'zac',
#  'efron',
#  'bad',
#  'anticipated',
#  'pretty',
#  'good',
#  'show',
#  'something',
#  'original',
#  'three',
#  'films',
#  'made',
#  'special',
#  'delightful',
#  'probably',
#  'length',
#  'unfortunately',
#  'lacks',
#  'charm',
#  'still',
#  'ends',
#  'fun',
#  'film',
#  'bright',
#  'shimmering',
#  'side',
#  'favourite',
#  ...]

# %%
vocabulary = set(tokens)
print(len(vocabulary))
print(vocabulary)
# Out:
# 96242
# {'marry', 'canninbals', 'shopgirl', 'lay', 'rouses', 'amazes', 'laid', 'straining', 'marion', 'seminar', 'shacks', 'digit', 'riddance', 'buduschego', 'metallers', 'supervising', 'bhandarkar', 'loof', 'congested', 'immoveable', 'hopers', 'repugnancy', 'genma', 'dimples', 'ripe', 'preparation', 'debatable', 'consolation', 'caped', 'pallance', 'mentor', 'infidelity', 'deflate', 'nuna', 'ninagawa', 'mikhail', 'arseholing', 'accelerates', 'houseguest', 'lidl', 'shanao', 'separate', 'dhol', 'serlingesque', 'thebes', 'groping', 'giancaspro', 'adoni', 'heating', 'psychiatrically', 'textile', 'dryden', 'conjunction', 'whitman', 'clans', 'monco', 'bumblebum', 'mower', 'cera', 'rabbitt', 'magus', 'leguizamo', 'fishburne', 'nearing', 'troublingly', 'compelling', 'reflect', 'lakin', 'gumming', 'samoans', 'talkies', 'outproduced', 'hystericly', 'beaubian', 'dhiraj', 'overracting', 'temuco', 'digicron', 'tailgate', 'arcaica', 'kafkian', 'namcos', 'shark', 'lessor', 'foundas', 'ewige', 'shine', 'colomb', 'haese', 'burdening', 'grabby', 'iolanthe', 'dillemas', 'spirit', 'abominator', 'babbles', 'starkly', 'officially', 'alfonso', 'cranked', 'debussy', 'badassness', 'projectors', 'lenders', 'piersanti', 'crimany', 'gramps', 'disengage', 'morsures', 'almast', 'laserblast', 'bekins', 'showoffy', 'vannoord', 'extraterritoriality', 'pities', 'momma', 'gyrations', 'millenni', 'hexing', 'ogend', 'gafones', 'hollywod', 'recored', 'bosnia', 'polk', 'vaccinated', 'rolle', 'legislated', 'exercizes', 'nosed', 'fozzy', 'overhead', 'irritation', 'anny', 'bodies', 'spats', 'hartemink', 'jasna', 'traffickers', 'din', 'olympias', 'ephemeralness', 'gwenn', 'serenely', 'programme', 'riffle', 'inaccuracy', 'engels', 'negulesco', 'bewitched', 'lasseter', 'clockworkish', 'logothetis', 'dysantry', 'shift', 'welch', 'grunberg', 'resist', 'unobservant', 'grid', 'phoebes', 'freckle', 'timewaves', 'haymes', 'lamented', 'contenting', 'premeditation', 'landy', 'laverack', 'rocketing', 'adagio', 'vuissa', 'pinata', 'gunships', 'dicpario', 'solanki', 'dde', 'hashing', 'pennelope', 'severe', 'zare', 'rosselinni', 'mooring', 'faubourg', 'lawbreaking', 'fotog', 'diel', 'uglying', 'notion', 'modulate', 'ckyish', 'dhalla', 'unequivically', 'personalize', 'enactment', 'passworthy', 'vogues', 'belaney', 'undeniable', 'additon', 'mastrontonio', 'underlie', 'oevure', 'headtripping', 'radium', 'pulsing', 'expressly', 'markerson', 'coriveau', 'shack', 'lmn', 'kold', 'occured', 'lostness', 'francs', 'inappropriateness', 'maserati', 'gnarly', 'unenjoyable', 'misjudgement', 'thesiger', 'helmond', 'reassurances', 'kalifonia', 'brontë', 'mylène', 'tenney', 'unopposed', 'mahendru', 'falcon', 'heeeeaaarrt', 'jellybeans', 'différence', 'aetheist', 'chambers', 'frazer', 'stepfathers', 'sola', 'duplicity', 'hyperdrive', 'burro', 'adventurous', 'aegean', 'honeycombs', 'rantzen', 'weskit', 'meaninglessness', 'biz', 'tripe', 'consultants', 'authenticate', 'doright', 'sullied', 'tynge', 'inclusion', 'bedouin', 'racoons', 'emigrant', 'dissertation', 'revival', 'roomy', 'garrard', 'waring', 'roué', 'monika', 'despot', 'wingtip', 'blandick', 'humperdink', 'dissappointment', 'modernization', 'chau', 'crump', 'docklands', 'looong', 'upscale', 'scantily', 'stakeholders', 'borske', 'lutz', 'plenty', 'heifers', 'congratulation', 'dissatisfied', 'nikolayev', 'kirie', 'heaths', 'beverly', 'brat', 'estela', 'kellerman', 'belén', 'osanna', 'grotesque', 'ranking', 'snoodle', 'maegi', 'morgus', 'copying', 'appreciations', 'rougish', 'fjernsynsteatret', 'copolla', 'cianfriglia', 'supernaturals', 'finalizes', 'concentric', 'homers', 'blax', 'amboy', 'gentrified', 'elijah', 'shamefully', 'prowess', 'silvery', 'female', 'stature', 'rhona', 'conlin', 'lasted', 'dardis', 'cataclysmic', 'roxborough', 'beeper', 'aplomb', 'ravishing', 'clohessy', 'vaio', 'wickedly', 'jtcellphone', 'jamesbondish', 'pimples', 'lemony', 'hjerner', 'liek', 'reverie', 'sunflower', 'shanley', 'messengers', 'macarther', 'assasination', 'sel', ' ...

# %%
freqDist = nltk.FreqDist(tokens)
freqDist = sorted(freqDist, key=freqDist.__getitem__, reverse=True)
freqDist[0:50]
# Out:
# ['movie',
#  'film',
#  'one',
#  'like',
#  'good',
#  'would',
#  'even',
#  'time',
#  'really',
#  'see',
#  'story',
#  'much',
#  'well',
#  'could',
#  'get',
#  'people',
#  'great',
#  'also',
#  'bad',
#  'first',
#  'made',
#  'make',
#  'way',
#  'movies',
#  'think',
#  'characters',
#  'watch',
#  'character',
#  'films',
#  'many',
#  'seen',
#  'two',
#  'never',
#  'love',
#  'acting',
#  'plot',
#  'best',
#  'know',
#  'show',
#  'little',
#  'life',
#  'ever',
#  'better',
#  'man',
#  'still',
#  'say',
#  'scene',
#  'end',
#  'scenes',
#  'something']

# %%
bow = pd.DataFrame(columns = freqDist)
bow
# Out:
# Empty DataFrame
# Columns: [movie, film, one, like, good, would, even, time, really, see, story, much, well, could, get, people, great, also, bad, first, made, make, way, movies, think, characters, watch, character, films, many, seen, two, never, love, acting, plot, best, know, show, little, life, ever, better, man, still, say, scene, end, scenes, something, back, watching, thing, real, actors, though, years, another, actually, funny, makes, nothing, find, look, work, director, going, lot, new, every, old, part, want, quite, things, cast, got, pretty, world, seems, around, young, take, however, fact, enough, give, thought, big, horror, may, without, long, right, saw, music, always, must, original, guy, ...]
# Index: []
#
# [0 rows x 96242 columns]

# %%
for index, row in df[0:10].iterrows():
  vocabDict = dict()
  for word in freqDist:
    vocabDict[word] = 0
  for word in row.review.split(" "):
    word = word.lower()
    if word in vocabDict.keys():
      vocabDict[word] += 1
  bow = bow.append(vocabDict, ignore_index = True)
bow.head()
# Out:
#   movie film one like good  ... colico misjudgement chronologies esqueleto chancho
# 0     3    0   0    3    0  ...      0            0            0         0       0
# 1     0    5   3    1    1  ...      0            0            0         0       0
# 2     2    0   1    0    1  ...      0            0            0         0       0
# 3     0    0   2    0    0  ...      0            0            0         0       0
# 4     4    1   0    2    0  ...      0            0            0         0       0
#
# [5 rows x 96242 columns]

# %% [markdown]
# # TF-IDF

# %%
df1 = df

# %%
df1
# Out:
#                                                   review
# 0      My children, DD 7 and DS 10, enjoyed the movie...
# 1      One of the many speculations about Y2K was tha...
# 2      Rajkumar Santoshi tries his hands at comedy an...
# 3      Bridget Fonda has disappointed me several time...
# 4      Watching this movie, I can't help drawing the ...
# ...                                                  ...
# 49995  The story and the show were good, but it was r...
# 49996  Mean spirited, and down right degrading adapta...
# 49997  "Nacho Libre" (2006) <br /><br />Directed By: ...
# 49998  I'm amazed how many comments on this show are ...
# 49999  I don't recall walking out of a movie theater ...
#
# [50000 rows x 1 columns]

# %%
vectorizer = TfidfVectorizer()
vectors = vectorizer.fit_transform(df1[0:100].review.values)

print(vectors.shape)
print(vectors)
# Out:
# (100, 4234)
#   (0, 4189)	0.10850984794906235
#   (0, 3543)	0.1262957044490089
#   (0, 3801)	0.06362613712990788
#   (0, 1648)	0.05951181416208668
#   (0, 2511)	0.06596043356519732
#   (0, 2494)	0.05515227844922266
#   (0, 2563)	0.09810578885338597
#   (0, 4108)	0.06991587325776305
#   (0, 1834)	0.09072399144911578
#   (0, 2429)	0.11589164535333253
#   (0, 3310)	0.1262957044490089
#   (0, 3682)	0.1262957044490089
#   (0, 1310)	0.08255260660849464
#   (0, 1854)	0.08499822455014798
#   (0, 3678)	0.1262957044490089
#   (0, 2610)	0.038598317724186856
#   (0, 2240)	0.15428091283414597
#   (0, 2282)	0.10850984794906235
#   (0, 2883)	0.11589164535333253
#   (0, 73)	0.1262957044490089
#   (0, 1846)	0.1262957044490089
#   (0, 191)	0.046404249858848674
#   (0, 1070)	0.0745941654544716
#   (0, 3787)	0.06077744113060842
#   (0, 3251)	0.0782660711353953
#   :	:
#   (99, 4119)	0.08524499424633636
#   (99, 4133)	0.09718721331375434
#   (99, 2502)	0.09075495545454615
#   (99, 2972)	0.1412794381703803
#   (99, 3822)	0.12387618298926058
#   (99, 248)	0.061906314476105784
#   (99, 4191)	0.1119339639218426
#   (99, 549)	0.05430717810051518
#   (99, 359)	0.06481366061510851
#   (99, 2035)	0.136801448102419
#   (99, 3599)	0.08930180019787445
#   (99, 2647)	0.1225865143510788
#   (99, 2494)	0.24828000052808297
#   (99, 1834)	0.13613793952704015
#   (99, 2610)	0.05791957959795039
#   (99, 191)	0.06963294780328112
#   (99, 3787)	0.045600482700806334
#   (99, 3251)	0.11744392513005239
#   (99, 3854)	0.1225865143510788
#   (99, 3817)	0.08336287468115436
#   (99, 2039)	0.04209770133206708
#   (99, 4122)	0.09383692340847866
#   (99, 3808)	0.08042570705816375
#   (99, 3789)	0.03850404419728878
#   (99, 196)	0.07777434435247361
